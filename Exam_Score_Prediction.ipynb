# %%
import pandas as pd

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("kundanbedmutha/exam-score-prediction-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'exam-score-prediction-dataset' dataset.
# Path to dataset files: /kaggle/input/exam-score-prediction-dataset

# %%
df = pd.read_csv('/kaggle/input/exam-score-prediction-dataset/Exam_Score_Prediction.csv')

# %%
df.head(5)
# Out:
#    student_id  age  gender   course  study_hours  class_attendance  \
# 0           1   17    male  diploma         2.78              92.9
# 1           2   23   other      bca         3.37              64.8
# 2           3   22    male     b.sc         7.88              76.8
# 3           4   20   other  diploma         0.67              48.4
# 4           5   20  female  diploma         0.89              71.6
#
#   internet_access  sleep_hours sleep_quality   study_method facility_rating  \
# 0             yes          7.4          poor       coaching             low
# 1             yes          4.6       average  online videos          medium
# 2             yes          8.5          poor       coaching            high
# 3             yes          5.8       average  online videos             low
# 4             yes          9.8          poor       coaching             low
#
#   exam_difficulty  exam_score
# 0            hard        58.9
# 1        moderate        54.8
# ...

# %%
df.shape
# Out:
# (20000, 13)

# %%
df.tail(5)
# Out:
#        student_id  age gender   course  study_hours  class_attendance  \
# 19995       19997   18  other      bba         6.50              71.3
# 19996       19998   18   male    b.com         3.71              41.6
# 19997       19999   19  other  diploma         7.88              68.2
# 19998       20000   19   male      bba         4.60              76.3
# 19999       20001   20   male     b.sc         7.50              47.9
#
#       internet_access  sleep_hours sleep_quality study_method facility_rating  \
# 19995             yes          5.0          good   self-study             low
# 19996              no          5.9       average     coaching          medium
# 19997             yes          4.6          poor  group study             low
# 19998              no          6.1          good   self-study          medium
# 19999             yes          7.5          poor     coaching          medium
#
#       exam_difficulty  exam_score
# 19995            easy        86.5
# ...

# %%
df.sample(5)
# Out:
#        student_id  age  gender   course  study_hours  class_attendance  \
# 6844         6845   19    male  diploma         4.59              87.1
# 3666         3667   21    male    b.com         1.16              97.6
# 18158       18159   24   other       ba         4.17              78.0
# 10819       10820   23    male  diploma         0.43              61.4
# 7559         7560   24  female    b.com         0.75              75.2
#
#       internet_access  sleep_hours sleep_quality study_method facility_rating  \
# 6844              yes          5.6          poor        mixed          medium
# 3666               no          8.3          good        mixed             low
# 18158             yes          7.4       average   self-study          medium
# 10819             yes          8.3       average     coaching            high
# 7559              yes          7.8          good   self-study          medium
#
#       exam_difficulty  exam_score
# 6844             easy        85.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   student_id        20000 non-null  int64
#  1   age               20000 non-null  int64
#  2   gender            20000 non-null  object
#  3   course            20000 non-null  object
#  4   study_hours       20000 non-null  float64
#  5   class_attendance  20000 non-null  float64
#  6   internet_access   20000 non-null  object
#  7   sleep_hours       20000 non-null  float64
#  8   sleep_quality     20000 non-null  object
#  9   study_method      20000 non-null  object
#  10  facility_rating   20000 non-null  object
#  11  exam_difficulty   20000 non-null  object
#  12  exam_score        20000 non-null  float64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 2.0+ MB

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'course', 'study_hours',
#        'class_attendance', 'internet_access', 'sleep_hours', 'sleep_quality',
#        'study_method', 'facility_rating', 'exam_difficulty', 'exam_score'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# student_id          0
# age                 0
# gender              0
# course              0
# study_hours         0
# class_attendance    0
# internet_access     0
# sleep_hours         0
# sleep_quality       0
# study_method        0
# facility_rating     0
# exam_difficulty     0
# exam_score          0
# dtype: int64

# %%
df['internet_access']
# Out:
# 0        yes
# 1        yes
# 2        yes
# 3        yes
# 4        yes
#         ...
# 19995    yes
# 19996     no
# 19997    yes
# 19998     no
# 19999    yes
# Name: internet_access, Length: 20000, dtype: object

# %%
df[['facility_rating','exam_score']]
# Out:
#       facility_rating  exam_score
# 0                 low        58.9
# 1              medium        54.8
# 2                high        90.3
# 3                 low        29.7
# 4                 low        43.7
# ...               ...         ...
# 19995             low        86.5
# 19996          medium        60.9
# 19997             low        64.5
# 19998          medium        79.0
# 19999          medium        71.0
#
# [20000 rows x 2 columns]

# %%
df.sample(5)[['facility_rating','exam_score']]
# Out:
#       facility_rating  exam_score
# 9449             high        77.2
# 5075           medium        56.2
# 17682             low        73.0
# 2302             high        42.6
# 11502            high        92.9

# %%
df['age'].unique()
# Out:
# array([17, 23, 22, 20, 18, 21, 24, 19])

# %%
df['age'].value_counts()
# Out:
# age
# 21    2555
# 18    2542
# 19    2528
# 17    2514
# 22    2497
# 20    2488
# 24    2443
# 23    2433
# Name: count, dtype: int64

# %%
df.drop(['study_hours'],axis=1).head(5)
# Out:
#    student_id  age  gender   course  class_attendance internet_access  \
# 0           1   17    male  diploma              92.9             yes
# 1           2   23   other      bca              64.8             yes
# 2           3   22    male     b.sc              76.8             yes
# 3           4   20   other  diploma              48.4             yes
# 4           5   20  female  diploma              71.6             yes
#
#    sleep_hours sleep_quality   study_method facility_rating exam_difficulty  \
# 0          7.4          poor       coaching             low            hard
# 1          4.6       average  online videos          medium        moderate
# 2          8.5          poor       coaching            high        moderate
# 3          5.8       average  online videos             low        moderate
# 4          9.8          poor       coaching             low        moderate
#
#    exam_score
# 0        58.9
# 1        54.8
# 2        90.3
# 3        29.7
# ...

# %%
df.head(5)
# Out:
#    student_id  age  gender   course  study_hours  class_attendance  \
# 0           1   17    male  diploma         2.78              92.9
# 1           2   23   other      bca         3.37              64.8
# 2           3   22    male     b.sc         7.88              76.8
# 3           4   20   other  diploma         0.67              48.4
# 4           5   20  female  diploma         0.89              71.6
#
#   internet_access  sleep_hours sleep_quality   study_method facility_rating  \
# 0             yes          7.4          poor       coaching             low
# 1             yes          4.6       average  online videos          medium
# 2             yes          8.5          poor       coaching            high
# 3             yes          5.8       average  online videos             low
# 4             yes          9.8          poor       coaching             low
#
#   exam_difficulty  exam_score
# 0            hard        58.9
# 1        moderate        54.8
# ...

# %%
df.loc[999]
# Out:
# student_id              1000
# age                       21
# gender                 other
# course                  b.sc
# study_hours             6.26
# class_attendance        66.3
# internet_access          yes
# sleep_hours              9.1
# sleep_quality           good
# study_method        coaching
# facility_rating       medium
# exam_difficulty         easy
# exam_score              88.5
# Name: 999, dtype: object

# %%
df.head(5)
# Out:
#    student_id  age  gender   course  study_hours  class_attendance  \
# 0           1   17    male  diploma         2.78              92.9
# 1           2   23   other      bca         3.37              64.8
# 2           3   22    male     b.sc         7.88              76.8
# 3           4   20   other  diploma         0.67              48.4
# 4           5   20  female  diploma         0.89              71.6
#
#   internet_access  sleep_hours sleep_quality   study_method facility_rating  \
# 0             yes          7.4          poor       coaching             low
# 1             yes          4.6       average  online videos          medium
# 2             yes          8.5          poor       coaching            high
# 3             yes          5.8       average  online videos             low
# 4             yes          9.8          poor       coaching             low
#
#   exam_difficulty  exam_score
# 0            hard        58.9
# 1        moderate        54.8
# ...

# %%
df.loc[999,'sleep_hours']
# Out:
# np.float64(9.1)

# %%
df.loc[999,['sleep_hours','study_hours']]
# Out:
# sleep_hours     9.1
# study_hours    6.26
# Name: 999, dtype: object

# %%
df.loc[:,['sleep_hours','study_hours']]
# Out:
#        sleep_hours  study_hours
# 0              7.4         2.78
# 1              4.6         3.37
# 2              8.5         7.88
# 3              5.8         0.67
# 4              9.8         0.89
# ...            ...          ...
# 19995          5.0         6.50
# 19996          5.9         3.71
# 19997          4.6         7.88
# 19998          6.1         4.60
# 19999          7.5         7.50
#
# [20000 rows x 2 columns]

# %%
df.drop(index=1,axis=0)
# Out:
#        student_id  age  gender   course  study_hours  class_attendance  \
# 0               1   17    male  diploma         2.78              92.9
# 2               3   22    male     b.sc         7.88              76.8
# 3               4   20   other  diploma         0.67              48.4
# 4               5   20  female  diploma         0.89              71.6
# 5               6   23    male   b.tech         3.48              65.4
# ...           ...  ...     ...      ...          ...               ...
# 19995       19997   18   other      bba         6.50              71.3
# 19996       19998   18    male    b.com         3.71              41.6
# 19997       19999   19   other  diploma         7.88              68.2
# 19998       20000   19    male      bba         4.60              76.3
# 19999       20001   20    male     b.sc         7.50              47.9
#
#       internet_access  sleep_hours sleep_quality   study_method  \
# ...

# %%
df
# Out:
#        student_id  age  gender   course  study_hours  class_attendance  \
# 0               1   17    male  diploma         2.78              92.9
# 1               2   23   other      bca         3.37              64.8
# 2               3   22    male     b.sc         7.88              76.8
# 3               4   20   other  diploma         0.67              48.4
# 4               5   20  female  diploma         0.89              71.6
# ...           ...  ...     ...      ...          ...               ...
# 19995       19997   18   other      bba         6.50              71.3
# 19996       19998   18    male    b.com         3.71              41.6
# 19997       19999   19   other  diploma         7.88              68.2
# 19998       20000   19    male      bba         4.60              76.3
# 19999       20001   20    male     b.sc         7.50              47.9
#
#       internet_access  sleep_hours sleep_quality   study_method  \
# ...

# %%
df.head()
# Out:
#    student_id  age  gender   course  study_hours  class_attendance  \
# 0           1   17    male  diploma         2.78              92.9
# 1           2   23   other      bca         3.37              64.8
# 2           3   22    male     b.sc         7.88              76.8
# 3           4   20   other  diploma         0.67              48.4
# 4           5   20  female  diploma         0.89              71.6
#
#   internet_access  sleep_hours sleep_quality   study_method facility_rating  \
# 0             yes          7.4          poor       coaching             low
# 1             yes          4.6       average  online videos          medium
# 2             yes          8.5          poor       coaching            high
# 3             yes          5.8       average  online videos             low
# 4             yes          9.8          poor       coaching             low
#
#   exam_difficulty  exam_score
# 0            hard        58.9
# 1        moderate        54.8
# ...

# %%
df.iloc[4,3]
# Out:
# 'diploma'

# %%
df
# Out:
#        student_id  age  gender   course  study_hours  class_attendance  \
# 0               1   17    male  diploma         2.78              92.9
# 1               2   23   other      bca         3.37              64.8
# 2               3   22    male     b.sc         7.88              76.8
# 3               4   20   other  diploma         0.67              48.4
# 4               5   20  female  diploma         0.89              71.6
# ...           ...  ...     ...      ...          ...               ...
# 19995       19997   18   other      bba         6.50              71.3
# 19996       19998   18    male    b.com         3.71              41.6
# 19997       19999   19   other  diploma         7.88              68.2
# 19998       20000   19    male      bba         4.60              76.3
# 19999       20001   20    male     b.sc         7.50              47.9
#
#       internet_access  sleep_hours sleep_quality   study_method  \
# ...

# %%
import numpy as np

# %%
# creating a synthetic data with null values
new_df = df.copy()
for i in range(0,20000,100):
  new_df.loc[i,'study_hours'] = np.nan

new_df.isnull().sum()
# Out:
# student_id            0
# age                   0
# gender                0
# course                0
# study_hours         200
# class_attendance      0
# internet_access       0
# sleep_hours           0
# sleep_quality         0
# study_method          0
# facility_rating       0
# exam_difficulty       0
# exam_score            0
# dtype: int64

# %%
new_df = new_df.dropna(axis=0)

# %%
new_df
# Out:
#        student_id  age  gender   course  study_hours  class_attendance  \
# 1               2   23   other      bca         3.37              64.8
# 2               3   22    male     b.sc         7.88              76.8
# 3               4   20   other  diploma         0.67              48.4
# 4               5   20  female  diploma         0.89              71.6
# 5               6   23    male   b.tech         3.48              65.4
# ...           ...  ...     ...      ...          ...               ...
# 19995       19997   18   other      bba         6.50              71.3
# 19996       19998   18    male    b.com         3.71              41.6
# 19997       19999   19   other  diploma         7.88              68.2
# 19998       20000   19    male      bba         4.60              76.3
# 19999       20001   20    male     b.sc         7.50              47.9
#
#       internet_access  sleep_hours sleep_quality   study_method  \
# ...

# %%
new_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   student_id        20000 non-null  int64
#  1   age               20000 non-null  int64
#  2   gender            20000 non-null  object
#  3   course            20000 non-null  object
#  4   study_hours       20000 non-null  float64
#  5   class_attendance  20000 non-null  float64
#  6   internet_access   20000 non-null  object
#  7   sleep_hours       20000 non-null  float64
#  8   sleep_quality     20000 non-null  object
#  9   study_method      20000 non-null  object
#  10  facility_rating   20000 non-null  object
#  11  exam_difficulty   20000 non-null  object
#  12  exam_score        20000 non-null  float64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 2.0+ MB

# %%
df.head()
# Out:
#    student_id  age  gender   course  study_hours  class_attendance  \
# 0           1   17    male  diploma         2.78              92.9
# 1           2   23   other      bca         3.37              64.8
# 2           3   22    male     b.sc         7.88              76.8
# 3           4   20   other  diploma         0.67              48.4
# 4           5   20  female  diploma         0.89              71.6
#
#   internet_access  sleep_hours sleep_quality   study_method facility_rating  \
# 0             yes          7.4          poor       coaching             low
# 1             yes          4.6       average  online videos          medium
# 2             yes          8.5          poor       coaching            high
# 3             yes          5.8       average  online videos             low
# 4             yes          9.8          poor       coaching             low
#
#   exam_difficulty  exam_score
# 0            hard        58.9
# 1        moderate        54.8
# ...

# %%
numerical_cols = df.select_dtypes(include=['float64', 'int64'])

print("Numerical Columns:")
print(numerical_cols.columns.tolist())
print("\n" + "="*60)

print("Describe:")
print(numerical_cols.describe())
print("\n" + "="*60)

print("Mean:")
print(numerical_cols.mean())
print("\n" + "="*60)

print("Correlation:")
print(numerical_cols.corr())
# Out:
# Numerical Columns:
# ['student_id', 'age', 'study_hours', 'class_attendance', 'sleep_hours', 'exam_score']
#
# ...
# Describe:
#          student_id           age   study_hours  class_attendance  \
# count  20000.000000  20000.000000  20000.000000      20000.000000
# mean   10000.504600     20.473300      4.007604         70.017365
# std     5773.654959      2.284458      2.308313         17.282262
# min        1.000000     17.000000      0.080000         40.600000
# 25%     5000.750000     18.000000      2.000000         55.100000
# 50%    10000.500000     20.000000      4.040000         69.900000
# 75%    15000.250000     22.000000      6.000000         85.000000
# max    20001.000000     24.000000      7.910000         99.400000
#
#        sleep_hours    exam_score
# count  20000.00000  20000.000000
# mean       7.00856     62.513225
# std        1.73209     18.908491
# min        4.10000     19.599000
# 25%        5.50000     48.800000
# 50%        7.00000     62.600000
# ...

# %%
categorical_cols = df.select_dtypes(include=['object'])

print("Categorical Columns:")
print(categorical_cols.columns.tolist())
print("\n" + "="*60)

print(categorical_cols.describe())
# Out:
# Categorical Columns:
# ['gender', 'course', 'internet_access', 'sleep_quality', 'study_method', 'facility_rating', 'exam_difficulty']
#
# ...
#        gender course internet_access sleep_quality study_method  \
# count   20000  20000           20000         20000        20000
# unique      3      7               2             3            5
# top     other    bca             yes       average   self-study
# freq     6726   2902           16988          6694         4079
#
#        facility_rating exam_difficulty
# count            20000           20000
# unique               3               3
# top             medium        moderate
# freq              6760            9878

# %%
df.isnull().sum()
# Out:
# student_id          0
# age                 0
# gender              0
# course              0
# study_hours         0
# class_attendance    0
# internet_access     0
# sleep_hours         0
# sleep_quality       0
# study_method        0
# facility_rating     0
# exam_difficulty     0
# exam_score          0
# dtype: int64
